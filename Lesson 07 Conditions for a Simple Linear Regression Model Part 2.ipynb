# %% [markdown]
# **SM339 &#x25aa; Applied Statistics &#x25aa; Spring 2023 &#x25aa; Uhan**

# %% [markdown]
# # Lesson 7. Conditions for a Simple Linear Regression Model &ndash; Part 2

# %% [markdown]
# ## Example

# %% [markdown]
# The cars in the `PorschePrice` data that we looked at previously in Lesson 6 were randomly selected from the Porsches for sale on Autotrader.com.

# %% [markdown]
# Let's start by loading the data:

# %%
library(Stat2Data)
data(PorschePrice)

# %% [markdown]
# As before, let's fit a simple linear regression model, with `Price` as the repsonse variable and `Mileage` as the explanatory variable:

# %%
fit <- lm(Price ~ Mileage, data = PorschePrice)

# %% [markdown]
# Now, let's look at the fitted line:

# %%
plot(PorschePrice$Mileage, PorschePrice$Price)
abline(fit)
# Out:
# plot without title

# %% [markdown]
# In R, we can obtain a __residuals vs. fitted values plot__ like this:

# %%
# Solution
plot(fit, which=1)
# Out:
# Plot with title “”

# %% [markdown]
# Similarly, we can obtain a __Normal Q-Q plot of the residuals__ like this:

# %%
# Solution
plot(fit, which=2)
# Out:
# Plot with title “”

# %% [markdown]
# Are the conditions of simple linear regression met? How do you know?

# %% [markdown]
# *Write your answer here. Double-click to edit.*
#
# - __Zero mean__
#
# - __Independence__
#
# - __Random__
#
# - __Linearity__
#
# - __Constant variance__
#
# - __Normality__

# %% [markdown]
# *Solution.*
#
# - __Zero mean__: Automatically satisfied.
#
# - __Independence__: Seems OK. Data randomly sampled. Can only generalize to Autotrader.com, though.
#
# - __Random__: Seems OK. Data randomly sampled. Can only generalize to Autotrader.com, though.
#
# - __Linearity__: Seems OK. Fitted vs. residuals looks pretty much like white noise.
#
# - __Constant variance__: Seems OK. Fitted vs. residuals looks like white noise.
#     (Note that point 24 makes the plot have a bit of fan shape, but not aggressively so.)
#
# - __Normality__: Seems OK. Normal Q-Q plot is an approximately straight line.
